# %% [markdown]
# # Data types in Python

# %% [markdown]
# ### [String](datatypes.ipynb)

# %% [markdown]
# ### [Integers](datatypes.ipynb)

# %% [markdown]
# ### [Floats](datatypes.ipynb)

# %% [markdown]
# ### [Complex Numbers](datatypes.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# # [Operators in python](operatorTutorial.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# # Built-in Data Structures in Python

# %% [markdown]
# ## [Lists](ListsTutorial.ipynb)

# %% [markdown]
# ## [Set](setTutorial.ipynb)

# %% [markdown]
# ## [Tuples](tupleTutorial.ipynb)

# %% [markdown]
# ## [Dictionary](dictionaryTutorial.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# # Control statement

# %% [markdown]
# ## [IF-ELIF-ELSE](controlstatement.ipynb)

# %% [markdown]
# ## [match statement](controlstatement.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# # Loops

# %% [markdown]
# ## [for loops](forloop.ipynb)

# %% [markdown]
# ## [while loops](whileloop.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## [Functions](functions.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ### Datetime module

# %% [markdown]
# ***

# %% [markdown]
# # Object Oriented Programming

# %% [markdown]
# ## [OOPS basics](oops.ipynb)

# %% [markdown]
# ## [Inheritance and Polymorphism](inheritance.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# # Intermediate Python

# %% [markdown]
# ### Lambda Functions

# %% [markdown]
# ### filter function

# %% [markdown]
# ### map(function, iterable)

# %% [markdown]
# ### Function Annotations (type hinting)

# %% [markdown]
# ### Generators

# %% [markdown]
# ### Decorators

# %% [markdown]
# # [Numpy](numpy.ipynb)

# %% [markdown]
# ## [Numpy Axes and Operations](complexnumpy.ipynb)

# %% [markdown]
# ## [numpy ufunc](ufunc.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## [MatPlotLib](matplotlib.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## [Pandas](pandas.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## [CSV Handling](csv_handling.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## File Handling

# %% [markdown]
# ***

# %% [markdown]
# ## Exception Handling

# %% [markdown]
# ***
